# %%
# !pip install dnspython
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: dnspython in /usr/local/lib/python3.7/dist-packages (2.2.1)
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.7/dist-packages (4.0.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from pymongo[srv]) (2.2.1)

# %%
import pymongo

cluster = pymongo.MongoClient("mongodb+srv://vaishnavi:Expo@cluster0.ucgs4.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = cluster.assignment

records=db.contacts
records.count_documents({})
# Out:
# 0

# %%
def register():
  db=open("database.txt","w")
  username=input("enter username:")
  email=input("enter email:")
  valid_email(email)
  password=input("enter password:")
  valid_password(password)
  password1=input("confirm password:")
  d=[]
  f=[]
  for i in db:
    a,b=i.split(",")
    b=b.strip()
    d.append(a)
    f.append(b)
  data=dict(zip(d,f))

  if password!=password1:
    print("password don't match, restart")
    register()
  else:
    if len(password)<=5:
     print("password is to short, restart")
     register()
    #elif username in d:
     #print("username exists")
      #register()
    else:
      db=open("database.txt","a")
      db.write(username+","+password+"\n")
      print("success!")


def access():
  db=open("database.txt","r")
  username=input("enter username:")
  password=input("enter password:")

  if not len(username or password)<1:
    d=[]
    f=[]
    for i in db:
      a,b=i.split(",")
      #b=b.strip()
      d.append(a)
      f.append(b)
    data=dict(zip(d,f))

  try:
   if password==data[username]:
      print("login success")
      print("hi", username)
   else :
      print("password or username incorrect")
  except:
       print("incorrect password or username")

def get_pass():
  db=open("database.txt","r")
  user=input("To access your forgoteen password,please enter your user name")
  users=[]
  passwords=[]
  for i in db:
    a,b=i.split(",")
    b=b.strip()
    users.append(a)
    passwords.append(b)
  info=dict(zip(users,passwords))

  if user in info:
    print("here is your password: ", info.get(user))
  else:
    print("user does not exist")
    print("you have to register")
    home()

def valid_email(email):
  if '@' not in email:
    print("please enter valid email")
    email=input("enter email:")
    ind=email.index("@")

    if '.' not in email:
      print("please enter valid email")
      email=input("enter email:")
      valid_email(email)

    
      if '.com' not in email[ind:] or '@.' in email:
         print("please enter a valid email")
         email=input("enter email:")
         valid_email(email)

def valid_password(pwd):
  symbols={'~',':',"'",'[','\\','@','^','{','%','(','-','"','*','|',',','&','<','`','}','.','_','=',']','!','>','>',';','?','#','$',')','/'}
  val=True

  if len(pwd)<5:
    print("length should be atleast 5 character")
    val=False
    password=input("enter password:")
    valid_password(password)

  elif len(pwd)>16:
    print("length should not greater then 16 character")
    val=False
    password=input("enter password:")
    valid_password(password)
  
  elif not any(char.isdigit() for char in pwd):
    print("password should have atleast one digit")
    val=False
    password=("enter password:")
    valid_password(password)

  elif not any(char.isupper() for char in pwd):
    print("password should have atleat one uppercase character")
    val=False
    password=input("enter password:")
    valid_password(password)

  elif not any(char.islower() for char in pwd):
    print("password should have atleast one lowercase character")
    val=False
    password=("enter password:")
    valid_password(password)
  
  elif not any(char in symbols for char in pwd):
    print("password should have atleast one special character")
    val=False
    password=input("enter password:")
    valid_password(password)
  
  elif val:
    return val



def home():
  option=input("login | signup | retrive_password")
  if option=="login":
    access()
  elif option=="signup":
    register()
  elif option=="retrive_password":
    get_pass()
  else:
    print("enter an option:")
home()
# Out:
# login | signup | retrive_passwordlogin
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-8406aac632d7> in <module>()
#     147   else:
#     148     print("enter an option:")
# --> 149 home()
#
# <ipython-input-6-8406aac632d7> in home()
#     140   option=input("login | signup | retrive_password")
#     141   if option=="login":
# --> 142     access()
#     143   elif option=="signup":
#     144     register()
#
# <ipython-input-6-8406aac632d7> in access()
#      33
#      34 def access():
# ---> 35   db=open("database.txt","r")
#      36   username=input("enter username:")
#      37   password=input("enter password:")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'database.txt'
